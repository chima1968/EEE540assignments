# %%
import numpy as np
import pandas as pd
import seaborn as sns
from icecream import ic

# %%
raw_df=pd.read_csv("D:/Halden/Downloads/auto+mpg/auto-mpg.data")
ic(raw_df.shape)
raw_df.head()
# Out:
# ic| Error: Failed to access the underlying source code for analysis. Was ic() invoked in a REPL (e.g. from the command line), a frozen application (e.g. packaged with PyInstaller), or did the underlying source code change during execution?
#   18.0   8   307.0      130.0      3504.      12.0   70  1\t"chevrolet chevelle malibu"
# 0  15.0   8   350.0      165.0      3693.      11...
# 1  18.0   8   318.0      150.0      3436.      11...
# 2  16.0   8   304.0      150.0      3433.      12...
# 3  17.0   8   302.0      140.0      3449.      10...
# 4  15.0   8   429.0      198.0      4341.      10...

# %%
file=open("D:/Halden/Downloads/auto+mpg/auto-mpg.data","r")
names=[]
for f in file: 
   
          
       
    names.append(f.strip(" "))
 
names[1]
# Out:
# '15.0   8   350.0      165.0      3693.      11.5   70  1\t"buick skylark 320"\n'

# %%
car_names=[]
for word in range(len(names)):
    cars=names[word][56:].strip("\t,\n")
    car_names.append(str(cars))
car_names
# Out:
# ['"chevrolet chevelle malibu"',
#  '"buick skylark 320"',
#  '"plymouth satellite"',
#  '"amc rebel sst"',
#  '"ford torino"',
#  '"ford galaxie 500"',
#  '"chevrolet impala"',
#  '"plymouth fury iii"',
#  '"pontiac catalina"',
#  '"amc ambassador dpl"',
#  '"dodge challenger se"',
#  '"plymouth \'cuda 340"',
#  '"chevrolet monte carlo"',
#  '"buick estate wagon (sw)"',
#  '"toyota corona mark ii"',
#  '"plymouth duster"',
#  '"amc hornet"',
#  '"ford maverick"',
#  '"datsun pl510"',
#  '"volkswagen 1131 deluxe sedan"',
#  '"peugeot 504"',
#  '"audi 100 ls"',
#  '"saab 99e"',
#  '"bmw 2002"',
#  '"amc gremlin"',
#  '"ford f250"',
#  '"chevy c20"',
#  '"dodge d200"',
#  '"hi 1200d"',
#  '"datsun pl510"',
#  '"chevrolet vega 2300"',
#  '"toyota corona"',
#  '"ford pinto"',
#  '"amc gremlin"',
#  '"plymouth satellite custom"',
#  '"chevrolet chevelle malibu"',
#  '"ford torino 500"',
#  '"amc matador"',
#  '"chevrolet impala"',
#  '"pontiac catalina brougham"',
#  '"ford galaxie 500"',
# ...

# %%
names[0][55:56]
# Out:
# '1'

# %%
mpg=[names[num][0:4] for num in range(len(names))]
mpg=list(map(float,mpg))

# %%
cylinders=list(map(int,[names[num][7:8] for num in range(len(names))]))

# %%
displacement=list(map(float,[names[num][11:16] for num in range(len(names))]))

# %%
horsepower=list(map(float,[names[num][22:27]   for num in range(len(names))]))
unknowns=[]
for val in range(len(horsepower)) :
    
    if  horsepower[val] == "?    ":
        
        unknowns.append(val)
unknowns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 horsepower=list(map([names[num][22:27]   for num in range(len(names))]))
#       2 unknowns=[]
#       3 for val in range(len(horsepower)) :
#
# TypeError: map() must have at least two arguments.

# %%
for num in unknowns:
    horsepower[num]=68.00

# %%
horsepower=list(map(float,[names[num][22:27]   for num in range(len(names))]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 horsepower=list(map(float,[names[num][22:27]   for num in range(len(names))]))
#
# ValueError: could not convert string to float: '?    '

# %%
horsepower=list(map(float,horsepower))

# %%
weight=list(map(float,[names[num][33:37]   for num in range(len(names))]))

# %%
acceleration=list(map(float,[names[num][44:48]   for num in range(len(names))]))

# %%
model_year=list(map(float,[names[num][51:53]   for num in range(len(names))]))

# %%
origin=list(map(float,[names[num][55:56]   for num in range(len(names))]))

# %%
auto=dict()
auto["mpg"]=mpg
auto["cylinders"]=cylinders
auto['displacement']=displacement
auto["horsepower"]=horsepower
auto["weight"]=weight
auto['acceleration']=acceleration
auto['model_year']=model_year
auto["origin"]=origin
auto["car_name"]=car_names

# %%
auto.values()
# Out:
# dict_values([[18.0, 15.0, 18.0, 16.0, 17.0, 15.0, 14.0, 14.0, 14.0, 15.0, 15.0, 14.0, 15.0, 14.0, 24.0, 22.0, 18.0, 21.0, 27.0, 26.0, 25.0, 24.0, 25.0, 26.0, 21.0, 10.0, 10.0, 11.0, 9.0, 27.0, 28.0, 25.0, 25.0, 19.0, 16.0, 17.0, 19.0, 18.0, 14.0, 14.0, 14.0, 14.0, 12.0, 13.0, 13.0, 18.0, 22.0, 19.0, 18.0, 23.0, 28.0, 30.0, 30.0, 31.0, 35.0, 27.0, 26.0, 24.0, 25.0, 23.0, 20.0, 21.0, 13.0, 14.0, 15.0, 14.0, 17.0, 11.0, 13.0, 12.0, 13.0, 19.0, 15.0, 13.0, 13.0, 14.0, 18.0, 22.0, 21.0, 26.0, 22.0, 28.0, 23.0, 28.0, 27.0, 13.0, 14.0, 13.0, 14.0, 15.0, 12.0, 13.0, 13.0, 14.0, 13.0, 12.0, 13.0, 18.0, 16.0, 18.0, 18.0, 23.0, 26.0, 11.0, 12.0, 13.0, 12.0, 18.0, 20.0, 21.0, 22.0, 18.0, 19.0, 21.0, 26.0, 15.0, 16.0, 29.0, 24.0, 20.0, 19.0, 15.0, 24.0, 20.0, 11.0, 20.0, 21.0, 19.0, 15.0, 31.0, 26.0, 32.0, 25.0, 16.0, 16.0, 18.0, 16.0, 13.0, 14.0, 14.0, 14.0, 29.0, 26.0, 26.0, 31.0, 32.0, 28.0, 24.0, 26.0, 24.0, 26.0, 31.0, 19.0, 18.0, 15.0, 15.0, 16.0, 15.0, 16.0, 14.0, 17.0, 16.0, 15.0, 18.0, 2
# ...

# %%
auto_mpg=pd.DataFrame(auto)

# %%
auto_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model_year  origin                     car_name
# 0          70.0     1.0  "chevrolet chevelle malibu"
# ...

# %%
sns.pairplot(auto_mpg)
p
# Out:
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
import matplotlib.pyplot as plt
auto_mpg.plot(kind='density', subplots=True, layout=(8,8), sharex=False, legend=False, figsize=(12,12), fontsize=1)
plt.show()

# %% [markdown]
# it looks like cars with higer horsepower had less acceleration

# %%
from sklearn.model_selection import train_test_split

# %%
x=auto_mpg[['displacement','horsepower','weight','acceleration']].values

# %%
y=auto_mpg['mpg'].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (278, 4)

# %%
y_train.shape
# Out:
# (278,)

# %% [raw]
# normalize and scale data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train=scaler.transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[0.72868217, 0.55307263, 0.80153105, 0.35714286],
#        [0.18604651, 0.1452514 , 0.22341934, 0.68452381],
#        [0.34108527, 0.21787709, 0.27615537, 0.47619048],
#        ...,
#        [0.17054264, 0.27374302, 0.25574142, 0.4047619 ],
#        [0.05426357, 0.08938547, 0.12390133, 0.55357143],
#        [0.0749354 , 0.        , 0.09554862, 0.77380952]])

# %%
x_train.max()
# Out:
# 1.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow'
